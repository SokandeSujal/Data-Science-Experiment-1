# %% [markdown]
# # **Merging Multiple Datasets**
#
# When we can merge datasets
#
# *   We have multiple small datasets
# *   We need a large dataset for deep learning

# %% [markdown]
# # **Example**
# ## **Problem Statement:**
#
# Predicting weight of person based on his/her height. Using height and weight datsets.
#
# ## **Datasets:**
# https://www.kaggle.com/mustafaali96/weight-height
#
# https://www.kaggle.com/burnoutminer/heights-and-weights-dataset

# %% [markdown]
# ## **Code**

# %%
import pandas as pd

# %% [markdown]
# ### **Dataset 1**

# %%
url1 = "/content/drive/MyDrive/Ds Data Sets/SOCR-HeightWeight.csv";
dataset1 = pd.read_csv(url1)

# %%
dataset1.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %% [markdown]
# ### **Dataset 2**

# %%
url2 = "/content/drive/MyDrive/Ds Data Sets/weight-height.csv";
dataset2 = pd.read_csv(url2)

# %%
print("dataset1:")
display(dataset1.head())
print("dataset2:")
display(dataset2.head())
# Out:
# dataset1:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# dataset2:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ### **Handling Features**

# %%
display(dataset1.head())
dataset1.drop(columns=['Index'],inplace=True)
display(dataset1.head())
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
#    Height(Inches)  Weight(Pounds)
# 0        65.78331        112.9925
# 1        71.51521        136.4873
# 2        69.39874        153.0269
# 3        68.21660        142.3354
# 4        67.78781        144.2971

# %%
display(dataset2.head())
dataset2.drop(columns=['Gender'],inplace=True)
display(dataset2.head())
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %% [markdown]
# Rename Feature/column names

# %%
dataset2.rename(columns = {'Height':'Height(Inches)','Weight':'Weight(Pounds)'},inplace=True)
dataset2.head()
# Out:
#    Height(Inches)  Weight(Pounds)
# 0       73.847017      241.893563
# 1       68.781904      162.310473
# 2       74.110105      212.740856
# 3       71.730978      220.042470
# 4       69.881796      206.349801

# %% [markdown]
# Total Records in each dataset

# %%
display(dataset1.shape,dataset2.shape)
# Out:
# (25000, 2)
# (10000, 2)

# %%
merged_dataset = pd.concat([dataset1,dataset2])
display(merged_dataset.shape)
# Out:
# (35000, 2)

# %%
merged_dataset.head()
# Out:
#    Height(Inches)  Weight(Pounds)
# 0        65.78331        112.9925
# 1        71.51521        136.4873
# 2        69.39874        153.0269
# 3        68.21660        142.3354
# 4        67.78781        144.2971

# %%
merged_dataset.to_csv('merged_dataset.csv', index=True)
print("Merged Dataset saved as 'merged_dataset.csv'")
# Out:
# Merged Dataset saved as 'merged_dataset.csv'

# %%
merged_dataset.dtypes
# Out:
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
merged_dataset.describe()
# Out:
#        Height(Inches)  Weight(Pounds)
# count    35000.000000    35000.000000
# mean        67.528670      136.896831
# std          2.711392       25.151985
# min         54.263133       64.700127
# 25%         66.100188      121.255650
# 50%         67.753785      130.729400
# 75%         69.257220      143.138175
# max         78.998742      269.989699
